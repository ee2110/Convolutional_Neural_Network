# %% [markdown]
# # Binary Classification using Deep Neural Network with Softmax

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

import os
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

print('TensorFlow version', tf.__version__)
# Out:
# TensorFlow version 2.3.1

# %%
import cv2
import glob
import shutil
from collections import Counter

from keras.callbacks import Callback
from keras.backend import clear_session

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Basic_CNN_Multi-Class_Classification_TF2.ipynb',
#  'cheesecake_vs_friedrice',
#  'dataset',
#  'DNN_Sigmoid_BinaryClassification_TF2.ipynb',
#  'DNN_Softmax_BinaryClassification_TF2.ipynb',
#  'DNN_Softmax_Multi-Class_Classification_TF2.ipynb',
#  'README.MD']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Food_Classification'

# %%
base_dir = os.path.join(os.getcwd(), 'cheesecake_vs_friedrice')
base_dir
# Out:
# 'C:\\Users\\user\\Food_Classification\\cheesecake_vs_friedrice'

# %%
classes = ['cheesecake', 'fried_rice']
classes
# Out:
# ['cheesecake', 'fried_rice']

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print("{}: {} Images".format(cl, len(images)))
  num_train = int(round(len(images)*0.8))
  train, val = images[:num_train], images[num_train:]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.copy(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.copy(v, os.path.join(base_dir, 'val', cl))
# Out:
# cheesecake: 50 Images
# fried_rice: 48 Images

# %%
# Set up path for training and validating path
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %% [markdown]
# # Augmentation to prevent overfitting
#
# Since the dataset we have currently is only small amount of training data, therefore we need to perform augmentation to prevent overfitting. Data augmentation takes the approach of generating more training data from existing training samples, by augmenting the samples via a number of random transformations that yield believable-looking images. The goal is that at training time, the model will never see the exact same picture twice. This helps expose the model to more aspects of the data and generalize better.
#
# By using ImageDataGenerator class from tf.keras, we able to perform on the fly preprocessing transformations to the dataset during our training process.

# %%
batch_size = 10
IMG_SHAPE = 150

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size, directory=train_dir, shuffle=True,target_size=(IMG_SHAPE,IMG_SHAPE))
# Out:
# Found 78 images belonging to 2 classes.

# %%
def plotImages(image_arr):
  fig, axes = plt.subplots(1, 5, figsize=(20,20))
  axes = axes.flatten()
  for img, ax in zip( image_arr, axes):
    ax.imshow(img)
  plt.tight_layout()
  plt.show()

augmented_images = [train_data_gen[6][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# Many cheese cakes!

# %%
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )


train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )

augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)
# Out:
# Found 78 images belonging to 2 classes.

# %%
# validation data

image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='binary')
# Out:
# Found 20 images belonging to 2 classes.

# %%
sample = val_data_gen[0][0][0]
plt.figure()
plt.imshow(sample, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Does this fried rice has any MSG? Uncle Roger might like this fried rice.

# %% [markdown]
# # Simple DNN model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(IMG_SHAPE,IMG_SHAPE,3)),
    tf.keras.layers.Dense(64, activation=tf.nn.relu),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(2, activation=tf.nn.softmax)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 67500)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4320064
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,328,642
# Trainable params: 4,328,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 2s 310ms/step - loss: 11.8810 - accuracy: 0.5000 - val_loss: 3.7515 - val_accuracy: 0.5000
# Epoch 2/100
# 8/8 [==============================] - 1s 172ms/step - loss: 2.8218 - accuracy: 0.5641 - val_loss: 3.7746 - val_accuracy: 0.5000
# Epoch 3/100
# 8/8 [==============================] - 1s 176ms/step - loss: 1.5094 - accuracy: 0.6410 - val_loss: 0.9166 - val_accuracy: 0.6500
# Epoch 4/100
# 8/8 [==============================] - 1s 183ms/step - loss: 1.7021 - accuracy: 0.5897 - val_loss: 1.5517 - val_accuracy: 0.6500
# Epoch 5/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.7209 - accuracy: 0.7308 - val_loss: 0.6797 - val_accuracy: 0.7000
# Epoch 6/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.8038 - accuracy: 0.7692 - val_loss: 0.8620 - val_accuracy: 0.7000
# Epoch 7/100
# 8/8 [==============================] - 1s 177ms/step - loss: 1.1360 - accuracy: 0.7436 - val_loss: 0.9431 - val_accuracy: 0.7000
# Epoch 8/100
# 8/8 [==============================] - 1s 180ms/step - loss: 0.7230 - accuracy: 0.7821 - val_loss: 0.8582 - val_accuracy: 0.7000
# Epoch 9/100
# 8/8 [==============================] - 1s 183ms/step - loss: 0.7653 - accuracy: 0.7308 - val_loss: 1.0535 - val_accuracy: 0.7000
# Epoch 10/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.9737 - accuracy: 0.7179 - val_loss: 0.5661 - val_accuracy: 0.8000
# Epoch 11/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.7422 - accuracy: 0.7308 - val_loss: 0.5262 - val_accuracy: 0.8000
# Epoch 12/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4782 - accuracy: 0.8333 - val_loss: 0.5448 - val_accuracy: 0.8000
# Epoch 13/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4604 - accuracy: 0.8077 - val_loss: 0.7871 - val_accuracy: 0.7000
# Epoch 14/100
# 8/8 [==============================] - 1s 180ms/step - loss: 0.6501 - accuracy: 0.7692 - val_loss: 0.4790 - val_accuracy: 0.8000
# Epoch 15/100
# 8/8 [==============================] - 1s 182ms/step - loss: 1.5613 - accuracy: 0.5641 - val_loss: 0.4102 - val_accuracy: 0.7500
# Epoch 16/100
# 8/8 [==============================] - 1s 177ms/step - loss: 1.4570 - accuracy: 0.5385 - val_loss: 3.1355 - val_accuracy: 0.5000
# Epoch 17/100
# 8/8 [==============================] - 1s 177ms/step - loss: 1.3264 - accuracy: 0.7821 - val_loss: 0.7195 - val_accuracy: 0.7500
# Epoch 18/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.6147 - accuracy: 0.8077 - val_loss: 0.5089 - val_accuracy: 0.7500
# Epoch 19/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.6239 - accuracy: 0.7436 - val_loss: 0.8071 - val_accuracy: 0.7000
# Epoch 20/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.7776 - accuracy: 0.7051 - val_loss: 0.5884 - val_accuracy: 0.7500
# Epoch 21/100
# 8/8 [==============================] - 1s 180ms/step - loss: 0.5737 - accuracy: 0.7564 - val_loss: 0.5440 - val_accuracy: 0.7000
# Epoch 22/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.4529 - accuracy: 0.8077 - val_loss: 0.4548 - val_accuracy: 0.8000
# Epoch 23/100
# 8/8 [==============================] - 1s 181ms/step - loss: 0.5464 - accuracy: 0.8077 - val_loss: 0.9416 - val_accuracy: 0.7500
# Epoch 24/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.5318 - accuracy: 0.7564 - val_loss: 1.5150 - val_accuracy: 0.6000
# Epoch 25/100
# 8/8 [==============================] - 1s 177ms/step - loss: 1.0151 - accuracy: 0.7179 - val_loss: 0.9662 - val_accuracy: 0.7000
# Epoch 26/100
# 8/8 [==============================] - 1s 179ms/step - loss: 1.2378 - accuracy: 0.6026 - val_loss: 0.6615 - val_accuracy: 0.8000
# Epoch 27/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.9525 - accuracy: 0.7179 - val_loss: 0.4962 - val_accuracy: 0.8000
# Epoch 28/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.4732 - accuracy: 0.8333 - val_loss: 0.4474 - val_accuracy: 0.8000
# Epoch 29/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.5792 - accuracy: 0.7308 - val_loss: 0.6309 - val_accuracy: 0.8000
# Epoch 30/100
# 8/8 [==============================] - 1s 184ms/step - loss: 0.7356 - accuracy: 0.6923 - val_loss: 0.4806 - val_accuracy: 0.6500
# Epoch 31/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.6772 - accuracy: 0.7051 - val_loss: 0.5042 - val_accuracy: 0.7500
# Epoch 32/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.4720 - accuracy: 0.8333 - val_loss: 0.4157 - val_accuracy: 0.8000
# Epoch 33/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4587 - accuracy: 0.7436 - val_loss: 0.4014 - val_accuracy: 0.8000
# Epoch 34/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.5021 - accuracy: 0.8077 - val_loss: 0.4344 - val_accuracy: 0.7000
# Epoch 35/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.7429 - accuracy: 0.6923 - val_loss: 0.3655 - val_accuracy: 0.8000
# Epoch 36/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.4912 - accuracy: 0.8077 - val_loss: 0.9737 - val_accuracy: 0.6500
# Epoch 37/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.6658 - accuracy: 0.7308 - val_loss: 0.4490 - val_accuracy: 0.6500
# Epoch 38/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.5541 - accuracy: 0.7821 - val_loss: 0.5534 - val_accuracy: 0.7500
# Epoch 39/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4816 - accuracy: 0.8333 - val_loss: 0.9778 - val_accuracy: 0.6500
# Epoch 40/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.8609 - accuracy: 0.7436 - val_loss: 0.3303 - val_accuracy: 0.8000
# Epoch 41/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.5681 - accuracy: 0.7821 - val_loss: 0.7969 - val_accuracy: 0.7500
# Epoch 42/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.7562 - accuracy: 0.7564 - val_loss: 0.4689 - val_accuracy: 0.6500
# Epoch 43/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.7812 - accuracy: 0.6538 - val_loss: 0.7076 - val_accuracy: 0.5500
# Epoch 44/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.5090 - accuracy: 0.7821 - val_loss: 0.3995 - val_accuracy: 0.8500
# Epoch 45/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.6119 - accuracy: 0.6795 - val_loss: 0.4161 - val_accuracy: 0.8000
# Epoch 46/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.6361 - accuracy: 0.7692 - val_loss: 0.4293 - val_accuracy: 0.8000
# Epoch 47/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.6588 - accuracy: 0.7179 - val_loss: 0.9546 - val_accuracy: 0.7000
# Epoch 48/100
# 8/8 [==============================] - 1s 176ms/step - loss: 1.2708 - accuracy: 0.6154 - val_loss: 0.6290 - val_accuracy: 0.7500
# Epoch 49/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.8211 - accuracy: 0.6026 - val_loss: 0.4978 - val_accuracy: 0.7500
# Epoch 50/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.4760 - accuracy: 0.7821 - val_loss: 0.4417 - val_accuracy: 0.8000
# Epoch 51/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.3846 - accuracy: 0.8205 - val_loss: 0.3683 - val_accuracy: 0.7000
# Epoch 52/100
# 8/8 [==============================] - 1s 179ms/step - loss: 0.3807 - accuracy: 0.8590 - val_loss: 0.4075 - val_accuracy: 0.8000
# Epoch 53/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.4525 - accuracy: 0.8077 - val_loss: 0.4504 - val_accuracy: 0.7000
# Epoch 54/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.7100 - accuracy: 0.7821 - val_loss: 0.4196 - val_accuracy: 0.8000
# Epoch 55/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.5342 - accuracy: 0.7436 - val_loss: 0.7974 - val_accuracy: 0.7000
# Epoch 56/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.8043 - accuracy: 0.6410 - val_loss: 0.3770 - val_accuracy: 0.7500
# Epoch 57/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.4134 - accuracy: 0.8590 - val_loss: 0.4851 - val_accuracy: 0.8000
# Epoch 58/100
# 8/8 [==============================] - 1s 175ms/step - loss: 0.4181 - accuracy: 0.8205 - val_loss: 0.4085 - val_accuracy: 0.8000
# Epoch 59/100
# 8/8 [==============================] - 1s 180ms/step - loss: 0.3713 - accuracy: 0.8590 - val_loss: 0.3932 - val_accuracy: 0.8000
# Epoch 60/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.3459 - accuracy: 0.8846 - val_loss: 0.3840 - val_accuracy: 0.8000
# Epoch 61/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.4585 - accuracy: 0.8077 - val_loss: 0.5821 - val_accuracy: 0.8000
# Epoch 62/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.4134 - accuracy: 0.8333 - val_loss: 0.3889 - val_accuracy: 0.8000
# Epoch 63/100
# 8/8 [==============================] - 1s 182ms/step - loss: 0.3734 - accuracy: 0.8462 - val_loss: 0.3658 - val_accuracy: 0.8000
# Epoch 64/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.3960 - accuracy: 0.8077 - val_loss: 0.3819 - val_accuracy: 0.7500
# Epoch 65/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4235 - accuracy: 0.8077 - val_loss: 0.4755 - val_accuracy: 0.8000
# Epoch 66/100
# 8/8 [==============================] - 1s 182ms/step - loss: 0.3793 - accuracy: 0.8077 - val_loss: 0.5238 - val_accuracy: 0.7000
# Epoch 67/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.5754 - accuracy: 0.7821 - val_loss: 0.3862 - val_accuracy: 0.8500
# Epoch 68/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.4830 - accuracy: 0.7692 - val_loss: 0.6211 - val_accuracy: 0.7500
# Epoch 69/100
# 8/8 [==============================] - 1s 178ms/step - loss: 0.5049 - accuracy: 0.7692 - val_loss: 0.3782 - val_accuracy: 0.8000
# Epoch 70/100
# 8/8 [==============================] - 1s 175ms/step - loss: 0.4304 - accuracy: 0.8205 - val_loss: 0.3396 - val_accuracy: 0.8500
# Epoch 71/100
# 8/8 [==============================] - 1s 176ms/step - loss: 0.3702 - accuracy: 0.8333 - val_loss: 0.3450 - val_accuracy: 0.8500
# Epoch 72/100
# 8/8 [==============================] - 1s 175ms/step - loss: 0.3383 - accuracy: 0.8462 - val_loss: 0.3680 - val_accuracy: 0.8500
# Epoch 73/100
# 8/8 [==============================] - 1s 177ms/step - loss: 0.4023 - accuracy: 0.7821 - val_loss: 0.3403 - val_accuracy: 0.8500
# Epoch 74/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.4262 - accuracy: 0.8718 - val_loss: 0.3570 - val_accuracy: 0.7500
# Epoch 75/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3724 - accuracy: 0.8462 - val_loss: 0.4641 - val_accuracy: 0.7500
# Epoch 76/100
# 8/8 [==============================] - 1s 187ms/step - loss: 0.3875 - accuracy: 0.7949 - val_loss: 0.4107 - val_accuracy: 0.7000
# Epoch 77/100
# 8/8 [==============================] - 2s 193ms/step - loss: 0.4410 - accuracy: 0.8205 - val_loss: 0.4075 - val_accuracy: 0.8500
# Epoch 78/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.4716 - accuracy: 0.8718 - val_loss: 0.4082 - val_accuracy: 0.8500
# Epoch 79/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.4445 - accuracy: 0.7949 - val_loss: 0.3944 - val_accuracy: 0.8500
# Epoch 80/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3597 - accuracy: 0.8846 - val_loss: 0.3443 - val_accuracy: 0.8000
# Epoch 81/100
# 8/8 [==============================] - 2s 192ms/step - loss: 0.4675 - accuracy: 0.7949 - val_loss: 0.3108 - val_accuracy: 0.8500
# Epoch 82/100
# 8/8 [==============================] - 1s 187ms/step - loss: 0.3672 - accuracy: 0.8077 - val_loss: 0.3244 - val_accuracy: 0.9000
# Epoch 83/100
# 8/8 [==============================] - 1s 187ms/step - loss: 0.3785 - accuracy: 0.8718 - val_loss: 0.3790 - val_accuracy: 0.8000
# Epoch 84/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3075 - accuracy: 0.9103 - val_loss: 0.2901 - val_accuracy: 0.8000
# Epoch 85/100
# 8/8 [==============================] - ETA: 0s - loss: 0.3242 - accuracy: 0.84 - 2s 189ms/step - loss: 0.3242 - accuracy: 0.8462 - val_loss: 0.3248 - val_accuracy: 0.8500
# Epoch 86/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3763 - accuracy: 0.8333 - val_loss: 0.3206 - val_accuracy: 0.8500
# Epoch 87/100
# 8/8 [==============================] - 2s 191ms/step - loss: 0.3296 - accuracy: 0.8590 - val_loss: 0.2925 - val_accuracy: 0.9000
# Epoch 88/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.3877 - accuracy: 0.8077 - val_loss: 0.2790 - val_accuracy: 0.9500
# Epoch 89/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.3707 - accuracy: 0.8718 - val_loss: 0.2747 - val_accuracy: 0.9000
# Epoch 90/100
# 8/8 [==============================] - 2s 190ms/step - loss: 0.3593 - accuracy: 0.8718 - val_loss: 0.3978 - val_accuracy: 0.7500
# Epoch 91/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.7437 - accuracy: 0.7436 - val_loss: 0.3047 - val_accuracy: 0.9000
# Epoch 92/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.4989 - accuracy: 0.7692 - val_loss: 0.6224 - val_accuracy: 0.6500
# Epoch 93/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.7005 - accuracy: 0.7051 - val_loss: 0.4025 - val_accuracy: 0.8500
# Epoch 94/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.4569 - accuracy: 0.7949 - val_loss: 0.6235 - val_accuracy: 0.7500
# Epoch 95/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.5818 - accuracy: 0.7692 - val_loss: 0.3412 - val_accuracy: 0.8000
# Epoch 96/100
# 8/8 [==============================] - 2s 194ms/step - loss: 0.4662 - accuracy: 0.7692 - val_loss: 0.3409 - val_accuracy: 0.9000
# Epoch 97/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.3517 - accuracy: 0.8590 - val_loss: 0.4081 - val_accuracy: 0.8500
# Epoch 98/100
# 8/8 [==============================] - 2s 188ms/step - loss: 0.4420 - accuracy: 0.8333 - val_loss: 4.8563 - val_accuracy: 0.5000
# Epoch 99/100
# 8/8 [==============================] - 2s 190ms/step - loss: 1.1736 - accuracy: 0.7692 - val_loss: 0.3468 - val_accuracy: 0.8000
# Epoch 100/100
# 8/8 [==============================] - 2s 189ms/step - loss: 0.2879 - accuracy: 0.9231 - val_loss: 0.3606 - val_accuracy: 0.8000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Test on unseen image from internet
#
# To test the modol, I simply download few images of fried rice and cheesecake from internet randomly.

# %%
# read test data
import PIL
import PIL.Image
import pathlib

test_dir = pathlib.Path(test_dir)

# %%
image_count = len(list(test_dir.glob('*')))
print('Total test file: ',image_count)
# Out:
# Total test file:  4

# %%
def normalize(images):
  images = tf.cast(images, tf.float32)
  images /= 255
  return images

# %%
test_image = list(test_dir.glob('*'))

plt.figure(figsize=(10,10))
for i in range(len(test_image)):
    img = PIL.Image.open(test_image[i])
    img = img.resize((IMG_SHAPE,IMG_SHAPE), PIL.Image.ANTIALIAS)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(img, cmap=plt.cm.binary)
plt.show()

# %%
sample_img1 = PIL.Image.open(test_image[1]).resize((IMG_SHAPE,IMG_SHAPE), PIL.Image.ANTIALIAS)
sample_img1
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x2E58ABAE48>

# %%
test_array = []
y_pred = []
score_list = []

for test_url in test_image:
    test_img = tf.keras.preprocessing.image.load_img(test_url, target_size=(IMG_SHAPE,IMG_SHAPE))
    img_array = tf.keras.preprocessing.image.img_to_array(test_img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    norm_img_array = normalize(img_array)
    test_array.append(norm_img_array)
    pred = model.predict(norm_img_array)[0]
    y_pred.append(np.argmax(pred))
    score = tf.nn.softmax(pred)
    score_list.append(score)

    print(
        "This food image is similar to {} with a {:.2f} percent confidence score."
        .format(classes[np.argmax(pred)], 100 * np.max(score))
    )
#     print('The actual file name is ', os.path.basename(os.path.normpath(test_url)))
# Out:
# This food image is similar to cheesecake with a 57.10 percent confidence score.
# This food image is similar to cheesecake with a 72.81 percent confidence score.
# This food image is similar to fried_rice with a 55.92 percent confidence score.
# This food image is similar to fried_rice with a 71.08 percent confidence score.

# %%
for i in range(len(test_image)):
    predictions_array, img = y_pred[i], test_image[i]

    img = PIL.Image.open(test_image[i])
    img = img.resize((IMG_SHAPE,IMG_SHAPE), PIL.Image.ANTIALIAS)
    plt.subplot(2,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    plt.imshow(img, cmap=plt.cm.binary)
    predicted_label = predictions_array


    plt.xlabel("Image {}, {} {:2.0f}%".format(i, classes[predicted_label],100*np.max(score_list[i])))

# %% [markdown]
# ### Manually Calculate F1 Score
#
# The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0. The relative contribution of precision and recall to the F1 score are equal.
#
#
# *Notes*
# Based on documentation from sklearn, the 'average' parameter is required for multiclass/multilabel targets. If None, the scores for each class are returned.
#
# 'micro': Calculate metrics globally by counting the total true positives, false negatives and false positives.
#
# 'macro': Calculate metrics for each label, and find their unweighted mean. This does not take label imbalance into account.
#
# 'weighted': Calculate metrics for each label, and find their average weighted by support (the number of true instances for each label). This alters ‘macro’ to account for label imbalance; it can result in an F-score that is not between precision and recall.

# %%
from sklearn.metrics import f1_score

# By default, the 0 is represent cheesecake, while 1 represents fried rice
y_true = [0, 0, 1, 1]

micro_f1_score = f1_score(y_true, y_pred, average='micro')
print('F1 score micro is ', micro_f1_score)
macro_f1_score = f1_score(y_true, y_pred, average='macro')
print('F1 score macro is ', macro_f1_score)
weighted_f1_score = f1_score(y_true, y_pred, average='weighted')
print('F1 score weighted is ', weighted_f1_score)
# Out:
# F1 score micro is  1.0
# F1 score macro is  1.0
# F1 score weighted is  1.0

# %%
print('Avg acc      :', np.mean(acc))
print('Avg val_acc  :', np.mean(val_acc))
print('Avg loss     :', np.mean(loss))
print('Avg val_loss :', np.mean(val_loss))
# Out:
# Avg acc      : 0.7717948693037033
# Avg val_acc  : 0.7605000025033951
# Avg loss     : 0.7446098002791405
# Avg val_loss : 0.6632324996590614
